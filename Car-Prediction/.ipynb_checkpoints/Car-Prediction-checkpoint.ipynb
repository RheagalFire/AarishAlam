# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#reading data
car=pd.read_excel("Data_Train.xlsx")
car_test = pd.read_excel("Data_Test.xlsx")

# %%
car.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# # FILLING NULL VALUES

# %%
car.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
car['Seats'].fillna(5,inplace=True)#usually 5 seats in a car

# %%
car['Engine'].fillna('0 CC',inplace=True)#Nan Values to some string values

# %%
car['Engine']=car['Engine'].apply(lambda x : x.split(' ')[0])

# %%
car.mean(axis=0)
# Out:
# Year                 2.013358e+03
# Kilometers_Driven    5.873838e+04
# Engine                        inf
# Seats                5.276790e+00
# Price                9.479468e+00
# dtype: float64

# %%
car['Engine']=car['Engine'].astype(str).astype(int)#tpecasting object to string to integer

# %%
car.mean(axis=0)
# Out:
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Engine                1611.579498
# Seats                    5.276790
# Price                    9.479468
# dtype: float64

# %%
car['Engine']=car['Engine'].replace(to_replace=0,value=1611)

# %%
car.mean(axis=0)
# Out:
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Engine                1621.214986
# Seats                    5.276790
# Price                    9.479468
# dtype: float64

# %%
car['Mileage'].fillna('0 kmpl',inplace=True)
car['Mileage']=car['Mileage'].apply(lambda x:x.split(' ')[0])

# %%
car['Mileage'].head()
# Out:
# 0     26.6
# 1    19.67
# 2     18.2
# 3    20.77
# 4     15.2
# Name: Mileage, dtype: object

# %%
car['Mileage']=car['Mileage'].astype(str).astype(float)

# %%
car['Mileage'].mean()
# Out:
# 18.12893503904303

# %%
car['Mileage']=car['Mileage'].replace(to_replace=0,value=18.12)

# %%
car['Mileage'].mean()
# Out:
# 18.33966771889018

# %%
Company_name=car['Name'].apply(lambda x:x.split(" ")[0])
car.insert(0,'Company',Company_name)

# %%
car.head()
# Out:
#    Company                              Name    Location  Year  \
# 0   Maruti            Maruti Wagon R LXI CNG      Mumbai  2010
# 1  Hyundai  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2    Honda                      Honda Jazz V     Chennai  2011
# 3   Maruti                 Maruti Ertiga VDI     Chennai  2012
# 4     Audi   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60     998
# 1              41000    Diesel       Manual      First    19.67    1582
# 2              46000    Petrol       Manual      First    18.20    1199
# 3              87000    Diesel       Manual      First    20.77    1248
# 4              40670    Diesel    Automatic     Second    15.20    1968
#
#        Power  Seats  Price
# 0  58.16 bhp    5.0   1.75
# 1  126.2 bhp    5.0  12.50
# 2   88.7 bhp    5.0   4.50
# 3  88.76 bhp    7.0   6.00
# 4  140.8 bhp    5.0  17.74

# %%
car['Company'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini'], dtype=object)

# %%
car['Company'].nunique()
# Out:
# 31

# %%
car=car.drop(['Name'],axis=1)

# %%
car['Power'].fillna('0 bhp',inplace=True)

# %%
car['Power']=car['Power'].apply(lambda x:x.split(' ')[0])

# %%
car['Power']=car['Power'].replace(to_replace='null',value='0')

# %%
car['Power']=car['Power'].astype(str).astype(float)

# %%
car['Power'].mean()
# Out:
# 110.5623724871241

# %%
car['Power']=car["Power"].replace(to_replace=0,value=110.56)

# %%
car['Power'].mean()
# Out:
# 113.18906795148696

# %%
car.head()
# Out:
#    Company    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti      Mumbai  2010              72000       CNG       Manual
# 1  Hyundai        Pune  2015              41000    Diesel       Manual
# 2    Honda     Chennai  2011              46000    Petrol       Manual
# 3   Maruti     Chennai  2012              87000    Diesel       Manual
# 4     Audi  Coimbatore  2013              40670    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine   Power  Seats  Price
# 0      First    26.60     998   58.16    5.0   1.75
# 1      First    19.67    1582  126.20    5.0  12.50
# 2      First    18.20    1199   88.70    5.0   4.50
# 3      First    20.77    1248   88.76    7.0   6.00
# 4     Second    15.20    1968  140.80    5.0  17.74

# %%
car.isnull().sum()
# Out:
# Company              0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
car['Kilometers_Driven']/=1000 #Trimming values

# %%
car.rename(columns={'Engine':'Engine(cc)','Mileage':'Mileage(kmpl)','Power':'Power(bhp)','Kilometers_Driven':'Kilometers_Driven(x10^3)'})
# Out:
#         Company    Location  Year  Kilometers_Driven(x10^3) Fuel_Type  \
# 0        Maruti      Mumbai  2010                    72.000       CNG
# 1       Hyundai        Pune  2015                    41.000    Diesel
# 2         Honda     Chennai  2011                    46.000    Petrol
# 3        Maruti     Chennai  2012                    87.000    Diesel
# 4          Audi  Coimbatore  2013                    40.670    Diesel
# ...         ...         ...   ...                       ...       ...
# 6014     Maruti       Delhi  2014                    27.365    Diesel
# 6015    Hyundai      Jaipur  2015                   100.000    Diesel
# 6016   Mahindra      Jaipur  2012                    55.000    Diesel
# 6017     Maruti     Kolkata  2013                    46.000    Petrol
# 6018  Chevrolet   Hyderabad  2011                    47.000    Diesel
#
#      Transmission Owner_Type  Mileage(kmpl)  Engine(cc)  Power(bhp)  Seats  \
# 0          Manual      First          26.60         998       58.16    5.0
# 1          Manual      First          19.67        1582      126.20    5.0
# 2          Manual      First          18.20        1199       88.70    5.0
# 3          Manual      First          20.77        1248       88.76    7.0
# 4       Automatic     Second          15.20        1968      140.80    5.0
# ...           ...        ...            ...         ...         ...    ...
# 6014       Manual      First          28.40        1248       74.00    5.0
# 6015       Manual      First          24.40        1120       71.00    5.0
# 6016       Manual     Second          14.00        2498      112.00    8.0
# 6017       Manual      First          18.90         998       67.10    5.0
# 6018       Manual      First          25.44         936       57.60    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
car_test['Seats'].fillna(5,inplace=True)

# %%
car_test['Engine'].fillna('0 CC',inplace=True)
car_test['Engine']=car_test['Engine'].apply(lambda x : x.split(' ')[0])
car_test['Engine']=car_test['Engine'].astype(str).astype(int)
car_test['Engine']=car_test['Engine'].replace(to_replace=0,value=1580)

# %%
Company_name=car_test['Name'].apply(lambda x:x.split(" ")[0])
car_test.insert(0,'Company',Company_name)
car_test=car_test.drop(['Name'],axis=1)

# %%
car_test['Mileage']=car_test['Mileage'].apply(lambda x:x.split(' ')[0])
car_test['Mileage']=car_test['Mileage'].astype(str).astype(float)
car_test['Mileage']=car_test['Mileage'].replace(to_replace=0,value=18.17)

# %%
car_test['Power'].fillna('0 bhp',inplace=True)
car_test['Power']=car_test['Power'].apply(lambda x:x.split(' ')[0])
car_test['Power']=car_test['Power'].replace(to_replace='null',value='0')
car_test['Power']=car_test['Power'].astype(str).astype(float)
car_test['Power']=car_test["Power"].replace(to_replace=0,value=107.51)

# %%
car_test['Kilometers_Driven']/=1000

# %%
car_test.head()
# Out:
#    Company    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti       Delhi  2014             40.929       CNG       Manual
# 1   Maruti  Coimbatore  2013             54.493    Petrol       Manual
# 2   Toyota      Mumbai  2017             34.000    Diesel       Manual
# 3   Toyota   Hyderabad  2012            139.000    Diesel       Manual
# 4  Hyundai      Mumbai  2014             29.000    Petrol       Manual
#
#   Owner_Type  Mileage  Engine   Power  Seats
# 0      First    32.26     998   58.20    4.0
# 1     Second    24.70     796   47.30    5.0
# 2      First    13.68    2393  147.80    7.0
# 3      First    23.59    1364  107.51    5.0
# 4      First    18.50    1197   82.85    5.0

# %% [markdown]
# # ANALYSING THE DATA

# %%
car.Location.unique()
# Out:
# array(['Mumbai', 'Pune', 'Chennai', 'Coimbatore', 'Hyderabad', 'Jaipur',
#        'Kochi', 'Kolkata', 'Delhi', 'Bangalore', 'Ahmedabad'],
#       dtype=object)

# %%
car.Year.nunique()
# Out:
# 22

# %%
car.Fuel_Type.unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
car.Fuel_Type.nunique()
# Out:
# 5

# %%
car.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
car.Owner_Type.unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
car.Seats.unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., 10.,  9.,  0.])

# %%
car.Seats.nunique()
# Out:
# 9

# %%
car.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  6019.000000        6019.000000  6019.000000  6019.000000  6019.000000
# mean   2013.358199          58.738380    18.339668  1621.214986   113.189068
# std       3.269742          91.268843     4.151188   599.554389    53.232600
# min    1998.000000           0.171000     6.400000    72.000000    34.200000
# 25%    2011.000000          34.000000    15.400000  1198.000000    78.000000
# 50%    2014.000000          53.000000    18.150000  1493.000000    98.600000
# 75%    2016.000000          73.000000    21.100000  1969.000000   138.030000
# max    2019.000000        6500.000000    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  6019.000000  6019.000000
# mean      5.276790     9.479468
# std       0.806346    11.187917
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# max      10.000000   160.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   float64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   int32
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int32(1), int64(1), object(5)
# memory usage: 540.9+ KB

# %% [markdown]
# # EDA

# %%
car.groupby('Company').Price.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Company'>

# %%
car['Fuel_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(car['Year'],kde=False,hist_kws=dict(edgecolor="b", linewidth=5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.distplot(car['Price'],kde=False,hist_kws=dict(edgecolor="k", linewidth=5))
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(car['Year'],kde=False,hist=True,bins=11,hist_kws=dict(edgecolor="b", linewidth=10))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.distplot(car['Price'],kde=False,hist=True,bins=11,hist_kws=dict(edgecolor="k", linewidth=10))
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(car['Price'],kde=False,norm_hist=True,bins=50)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(car['Year'],kde=False,norm_hist=True,bins=10)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.kdeplot(car['Year'],shade=False)
sns.kdeplot(car['Price'],shade=False)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(car['Price'],shade=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(car['Year'],kde=True,bins=10, hist=False)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.violinplot(y='Year',data=car)
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
sns.violinplot(y='Price',data=car)
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   float64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   int32
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int32(1), int64(1), object(5)
# memory usage: 540.9+ KB

# %%
sns.jointplot(x="Year", y="Price",data=car)

# %%
sns.jointplot(x="Price", y="Year", data=car.loc[(car['Price']>0)&(car['Price']<100),:],kind="hex",height=5,color="g")

# %%
sns.jointplot(x="Price",y="Year",data=car.iloc[:100,:], kind="hex",size=5,color="g")

# %%
sns.lmplot('Year','Price',data=car,order=1)

# %%
sns.lmplot('Year', 'Price', data=car,hue='Transmission')

# %%
sns.lmplot('Year', 'Price', data=car,hue='Location')

# %%
sns.lmplot('Year', 'Price', data=car,hue='Fuel_Type')

# %%
sns.lmplot('Year', 'Price', data=car,hue='Owner_Type')

# %%
sns.lmplot('Year', 'Price', data=car, hue='Fuel_Type',col='Transmission')

# %%
sns.lmplot('Year', 'Price', data=car, hue='Location',col='Transmission')

# %%
car.Location.value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
car['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
car['Fuel_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
car['Location'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
car['Transmission'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
car['Owner_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="Fuel_Type", data=car, hue = 'Transmission')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %%
sns.countplot(x="Owner_Type", data=car, hue = 'Fuel_Type')
# Out:
# <AxesSubplot:xlabel='Owner_Type', ylabel='count'>

# %% [markdown]
# # CORRELATION

# %%
car.corr()
# Out:
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.173048  0.291343 -0.051582  0.015682
# Kilometers_Driven -0.173048           1.000000 -0.064281  0.091018  0.033191
# Mileage            0.291343          -0.064281  1.000000 -0.639838 -0.548295
# Engine            -0.051582           0.091018 -0.639838  1.000000  0.859344
# Power              0.015682           0.033191 -0.548295  0.859344  1.000000
# Seats              0.015204           0.082782 -0.341326  0.393017  0.100598
# Price              0.305327          -0.011493 -0.329994  0.657143  0.767852
#
#                       Seats     Price
# Year               0.015204  0.305327
# Kilometers_Driven  0.082782 -0.011493
# Mileage           -0.341326 -0.329994
# Engine             0.393017  0.657143
# Power              0.100598  0.767852
# Seats              1.000000  0.052811
# Price              0.052811  1.000000

# %%
corr=car.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(car)

# %% [markdown]
# Inter-Quantile Range is a way to remove outliers from our Dataset anaways i have used boxplot way to remove outliers but the same way of doing so is manually finding out the IQR.

# %%
Q1 = car['Price'].quantile(0.25)
print(Q1)
Q3 =car['Price'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 3.5
# 9.95
# 6.449999999999999
# -6.174999999999999
# 19.625

# %%
Q1 = car['Kilometers_Driven'].quantile(0.25)
print(Q1)
Q3 =car['Kilometers_Driven'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 34.0
# 73.0
# 39.0
# -24.5
# 131.5

# %% [markdown]
# # FINDING AND REMOVING OUTLIERS

# %%
sns.boxplot(car['Mileage'])
# Out:
# <AxesSubplot:xlabel='Mileage'>

# %% [markdown]
# As Seen there are outliers.

# %%
car[car['Mileage'] > 30].head()
# Out:
#      Company Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 1269  Maruti   Mumbai  2018             10.600       CNG       Manual
# 1332  Maruti     Pune  2013             79.494       CNG       Manual
# 2059  Maruti   Mumbai  2013             54.000       CNG       Manual
# 2371  Maruti     Pune  2014             29.202       CNG       Manual
# 2701  Maruti    Kochi  2016             70.536       CNG       Manual
#
#      Owner_Type  Mileage  Engine  Power  Seats  Price
# 1269      First    33.44     796  40.30    4.0   3.50
# 1332      First    33.54     998  67.04    5.0   2.96
# 2059      First    33.54     998  67.04    5.0   3.05
# 2371      First    33.54     998  67.04    5.0   3.90
# 2701      First    31.79     998  58.33    5.0   4.58

# %%
index = car[(car['Mileage'] >30)].index
car.drop(index, inplace=True)
car['Mileage'].describe()
# Out:
# count    6005.000000
# mean       18.305818
# std         4.096071
# min         6.400000
# 25%        15.400000
# 50%        18.120000
# 75%        21.100000
# max        28.400000
# Name: Mileage, dtype: float64

# %%
sns.boxplot(car['Kilometers_Driven'])
# Out:
# <AxesSubplot:xlabel='Kilometers_Driven'>

# %%
car[car['Kilometers_Driven'] > 500].head(1000)
# Out:
#          Company Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 340        Skoda  Kolkata  2013              775.0    Diesel    Automatic
# 358      Hyundai  Chennai  2009              620.0    Petrol       Manual
# 1860  Volkswagen  Chennai  2013              720.0    Diesel       Manual
# 2328         BMW  Chennai  2017             6500.0    Diesel    Automatic
#
#      Owner_Type  Mileage  Engine  Power  Seats  Price
# 340       First    19.30    1968  141.0    5.0    7.5
# 358       First    20.36    1197   78.9    5.0    2.7
# 1860      First    20.54    1598  103.6    5.0    5.9
# 2328      First    15.97    2993  258.0    5.0   65.0

# %%
index = car[(car['Kilometers_Driven'] >1000)].index
car.drop(index, inplace=True)
car['Kilometers_Driven'].describe()
# Out:
# count    6004.000000
# mean       57.691232
# std        37.905231
# min         0.171000
# 25%        34.000000
# 50%        53.000000
# 75%        73.000000
# max       775.000000
# Name: Kilometers_Driven, dtype: float64

# %%
sns.boxplot(car['Engine'])
# Out:
# <AxesSubplot:xlabel='Engine'>

# %%
car[car['Engine'] > 3000].head(1000)
# Out:
#             Company    Location  Year  Kilometers_Driven Fuel_Type  \
# 70          Porsche      Mumbai  2008             73.000    Petrol
# 152   Mercedes-Benz     Kolkata  2010             35.277    Petrol
# 459            Audi  Coimbatore  2016             51.002    Diesel
# 586            Audi       Kochi  2014             79.926    Diesel
# 589   Mercedes-Benz   Bangalore  2006             47.088    Petrol
# ...             ...         ...   ...                ...       ...
# 5728  Mercedes-Benz     Kolkata  2009             43.600    Petrol
# 5781    Lamborghini       Delhi  2011              6.500    Petrol
# 5885  Mercedes-Benz        Pune  2010             93.000    Petrol
# 5919         Jaguar   Hyderabad  2015              8.000    Petrol
# 6011          Skoda   Hyderabad  2009             53.000    Petrol
#
#      Transmission Owner_Type  Mileage  Engine  Power  Seats   Price
# 70      Automatic      First     8.50    4806  500.0    5.0   14.50
# 152     Automatic      First     7.81    5461  362.9    5.0   30.00
# 459     Automatic      First    11.33    4134  335.2    7.0   48.91
# 586     Automatic      First    11.33    4134  335.2    7.0   29.77
# 589     Automatic     Second    10.13    3498  364.9    5.0   19.00
# ...           ...        ...      ...     ...    ...    ...     ...
# 5728    Automatic      First    10.93    3498  272.0    5.0   10.24
# 5781    Automatic      Third     6.40    5204  560.0    2.0  120.00
# 5885    Automatic     Second    11.80    3498  272.0    7.0   15.00
# 5919    Automatic      First    12.50    5000  488.1    2.0  100.00
# 6011    Automatic      First    18.12    3597  262.6    5.0    4.75
#
# [61 rows x 12 columns]

# %% [markdown]
# These are high end cars as evident from the company

# %%
index = car[(car['Engine'] >3000)].index
car.drop(index, inplace=True)
car['Engine'].describe()
# Out:
# count    5943.0000
# mean     1598.8351
# std       548.9450
# min        72.0000
# 25%      1198.0000
# 50%      1493.0000
# 75%      1968.0000
# max      2999.0000
# Name: Engine, dtype: float64

# %%
sns.boxplot(car['Power'])
# Out:
# <AxesSubplot:xlabel='Power'>

# %%
car[car['Power'] > 300].head(1000)
# Out:
#             Company    Location  Year  Kilometers_Driven Fuel_Type  \
# 134   Mercedes-Benz     Kolkata  2017             13.372    Petrol
# 148            Audi      Mumbai  2013             23.000    Petrol
# 326             BMW      Mumbai  2011             30.000    Diesel
# 418   Mercedes-Benz  Coimbatore  2018             22.397    Petrol
# 1123            BMW        Pune  2008             66.000    Petrol
# 1741            BMW   Hyderabad  2013             58.000    Diesel
# 1974            BMW  Coimbatore  2018             28.060    Petrol
# 1984            BMW   Bangalore  2017             17.465    Petrol
# 2089            BMW      Mumbai  2013             30.000    Diesel
# 2095  Mercedes-Benz  Coimbatore  2019              2.526    Petrol
# 2515            BMW       Delhi  2013             21.000    Diesel
# 2547            BMW     Chennai  2016             25.000    Diesel
# 2907         Jaguar   Hyderabad  2015             26.000    Diesel
# 3132        Porsche       Kochi  2019             14.298    Petrol
# 3266  Mercedes-Benz     Kolkata  2015              7.501    Petrol
# 4061           Audi      Mumbai  2013             23.312    Petrol
# 4360            BMW       Kochi  2018             20.004    Diesel
# 4816            BMW       Delhi  2006             48.000    Petrol
# 4893            BMW       Kochi  2018              9.952    Petrol
# 5294            BMW       Delhi  2011             25.000    Petrol
# 5535            BMW   Ahmedabad  2015             97.003    Diesel
# 5775            BMW      Mumbai  2013             30.000    Diesel
#
#      Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 134     Automatic      First    19.00    2996  362.07    2.0  54.00
# 148     Automatic      First    11.05    2894  444.00    4.0  37.00
# 326     Automatic      First     9.52    2993  313.00    4.0  49.00
# 418     Automatic      First    11.50    2996  367.00    5.0  70.99
# 1123    Automatic     Second     8.45    2979  321.00    5.0  10.75
# 1741    Automatic      First    11.20    2993  306.00    4.0  48.00
# 1974    Automatic      First    12.05    2979  320.00    5.0  93.67
# 1984    Automatic      First    12.05    2979  320.00    5.0  93.00
# 2089    Automatic      First     9.52    2993  313.00    4.0  45.00
# 2095    Automatic      First    19.00    2996  362.07    2.0  83.96
# 2515    Automatic     Second    17.54    2993  313.00    4.0  44.00
# 2547    Automatic      First    15.87    2993  308.43    5.0  60.00
# 2907    Automatic      First    14.47    2993  301.73    5.0  75.00
# 3132    Automatic      First    13.33    2995  340.00    5.0   2.02
# 3266    Automatic      First    10.00    2996  333.00    4.0  48.00
# 4061    Automatic      First    11.05    2894  444.00    4.0  40.50
# 4360    Automatic      First    17.54    2993  313.00    4.0  68.94
# 4816    Automatic     Second    11.62    2979  306.00    5.0   6.99
# 4893    Automatic      First    10.37    2979  306.00    2.0  58.54
# 5294    Automatic      First    10.37    2979  306.00    2.0  30.00
# 5535    Automatic      First    15.87    2993  308.43    5.0  85.00
# 5775    Automatic      First    17.54    2993  313.00    4.0  45.00

# %% [markdown]
# These are high end cars as evident from the company

# %%
index = car[(car['Power'] >300)].index
car.drop(index, inplace=True)
car['Power'].describe()
# Out:
# count    5921.000000
# mean      110.498093
# std        46.576142
# min        34.200000
# 25%        77.000000
# 50%        98.600000
# 75%       136.000000
# max       300.000000
# Name: Power, dtype: float64

# %%
car.Price
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 5921, dtype: float64

# %%
car.head(5921)
# Out:
#         Company    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010             72.000       CNG       Manual
# 1       Hyundai        Pune  2015             41.000    Diesel       Manual
# 2         Honda     Chennai  2011             46.000    Petrol       Manual
# 3        Maruti     Chennai  2012             87.000    Diesel       Manual
# 4          Audi  Coimbatore  2013             40.670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014             27.365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015            100.000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012             55.000    Diesel       Manual
# 6017     Maruti     Kolkata  2013             46.000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011             47.000    Diesel       Manual
#
#      Owner_Type  Mileage  Engine   Power  Seats  Price
# 0         First    26.60     998   58.16    5.0   1.75
# 1         First    19.67    1582  126.20    5.0  12.50
# 2         First    18.20    1199   88.70    5.0   4.50
# 3         First    20.77    1248   88.76    7.0   6.00
# 4        Second    15.20    1968  140.80    5.0  17.74
# ...         ...      ...     ...     ...    ...    ...
# 6014      First    28.40    1248   74.00    5.0   4.75
# 6015      First    24.40    1120   71.00    5.0   4.00
# 6016     Second    14.00    2498  112.00    8.0   2.90
# 6017      First    18.90     998   67.10    5.0   2.65
# 6018      First    25.44     936   57.60    5.0   2.50
#
# [5921 rows x 12 columns]

# %%
car.isnull().sum()
# Out:
# Company              0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# # SPLITTING TRAINING AND TESTING DATA

# %%
from sklearn.model_selection import train_test_split

y = np.log1p(car.Price) #takin log increases accuracy 
X = car.drop(['Price'],axis=1)


X_train, X_valid, y_train, y_valid = train_test_split(X,y,train_size=0.82,test_size=0.18,random_state=0)

# %%
X_train.head()
# Out:
#             Company   Location  Year  Kilometers_Driven Fuel_Type  \
# 3929          Honda  Hyderabad  2017             12.538    Petrol
# 2057        Hyundai    Kolkata  2009             65.000    Diesel
# 4731         Nissan       Pune  2018             24.000    Petrol
# 953          Maruti       Pune  2016             14.930    Petrol
# 3349  Mercedes-Benz       Pune  2010            130.923    Diesel
#
#      Transmission Owner_Type  Mileage  Engine   Power  Seats
# 3929    Automatic      First    18.00    1497  117.30    5.0
# 2057       Manual     Second    13.60    1991  142.00    5.0
# 4731       Manual      First    19.69    1198   67.04    5.0
# 953        Manual      First    21.40    1197   83.10    5.0
# 3349    Automatic      First    14.21    2143  203.00    5.0

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()



X_train['Company'] = label_encoder.fit_transform(X_train['Company'])
X_valid['Company'] = label_encoder.fit_transform(X_valid['Company'])
car_test['Company'] = label_encoder.fit_transform(car_test['Company'])

X_train['Location'] = label_encoder.fit_transform(X_train['Location'])
X_valid['Location'] = label_encoder.fit_transform(X_valid['Location'])
car_test['Location'] = label_encoder.fit_transform(car_test['Location'])

X_train['Fuel_Type'] = label_encoder.fit_transform(X_train['Fuel_Type'])
X_valid['Fuel_Type'] = label_encoder.fit_transform(X_valid['Fuel_Type'])
car_test['Fuel_Type'] = label_encoder.fit_transform(car_test['Fuel_Type'])


X_train['Transmission'] = label_encoder.fit_transform(X_train['Transmission'])
X_valid['Transmission'] = label_encoder.fit_transform(X_valid['Transmission'])
car_test['Transmission'] = label_encoder.fit_transform(car_test['Transmission'])


X_train['Owner_Type'] = label_encoder.fit_transform(X_train['Owner_Type'])
X_valid['Owner_Type'] = label_encoder.fit_transform(X_valid['Owner_Type'])
car_test['Owner_Type'] = label_encoder.fit_transform(car_test['Owner_Type'])

# %%
car_test
# Out:
#       Company  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0          16         4  2014             40.929          0             1
# 1          16         3  2013             54.493          3             1
# 2          26         9  2017             34.000          1             1
# 3          26         5  2012            139.000          1             1
# 4           9         9  2014             29.000          3             1
# ...       ...       ...   ...                ...        ...           ...
# 1229       27         5  2011             89.411          1             1
# 1230       27         9  2015             59.000          3             0
# 1231       20         8  2012             28.000          1             1
# 1232       27        10  2013             52.262          3             0
# 1233       17         7  2014             72.443          1             0
#
#       Owner_Type  Mileage  Engine   Power  Seats
# 0              0    32.26     998   58.20    4.0
# 1              2    24.70     796   47.30    5.0
# 2              0    13.68    2393  147.80    7.0
# 3              0    23.59    1364  107.51    5.0
# 4              0    18.50    1197   82.85    5.0
# ...          ...      ...     ...     ...    ...
# 1229           0    20.54    1598  103.60    5.0
# 1230           0    17.21    1197  103.60    5.0
# 1231           0    23.08    1461   63.10    5.0
# 1232           3    17.20    1197  103.60    5.0
# 1233           0    10.00    2148  170.00    5.0
#
# [1234 rows x 11 columns]

# %%
X_train.head()
# Out:
#       Company  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 3929        8         5  2017             12.538          4             0
# 2057        9         8  2009             65.000          1             1
# 4731       19        10  2018             24.000          4             1
# 953        15        10  2016             14.930          4             1
# 3349       16        10  2010            130.923          1             0
#
#       Owner_Type  Mileage  Engine   Power  Seats
# 3929           0    18.00    1497  117.30    5.0
# 2057           2    13.60    1991  142.00    5.0
# 4731           0    19.69    1198   67.04    5.0
# 953            0    21.40    1197   83.10    5.0
# 3349           0    14.21    2143  203.00    5.0

# %% [markdown]
# # LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
plt.show()

# %%
y_pred = reg.predict(X_valid)

# %%
df = pd.DataFrame({'Actual': y_valid, 'Predicted': y_pred})
df
# Out:
#         Actual  Predicted
# 1407  2.802754   3.218169
# 5121  1.252763   1.083665
# 2765  1.704748   1.996567
# 1856  1.808289   1.992640
# 748   1.163151   1.144003
# ...        ...        ...
# 1569  2.079442   2.074202
# 3966  2.564949   2.526250
# 97    1.492904   1.806370
# 4166  4.043051   3.919596
# 4868  2.847812   2.873585
#
# [1066 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("MAE: " + str(mean_absolute_error(y_pred, y_valid)))
print("MSE: " + str(mean_squared_error(y_pred, y_valid)))
# Out:
# MAE: 0.18936994245217054
# MSE: 0.06117303034635058

# %%
reg.score(X_valid,y_valid)
# Out:
# 0.8799736183553446

# %%
plt.scatter(y_valid,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # SVM MODEL

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
sc_X = StandardScaler()
X_train1=X_train
X_valid1=X_valid
X_train1= sc_X.fit_transform(X_train)
X_valid1 = sc_X.fit_transform(X_valid)

# %%
regressor1 = SVR(kernel='poly')
regressor1.fit(X_train1, y_train)
# Out:
# SVR(kernel='poly')

# %%
y_pred1 = regressor1.predict(X_valid1)

# %%
df1= pd.DataFrame({'Actual': y_valid, 'Predicted': y_pred1})
df1
# Out:
#         Actual  Predicted
# 1407  2.802754   3.066569
# 5121  1.252763   1.116962
# 2765  1.704748   1.971847
# 1856  1.808289   1.966613
# 748   1.163151   1.072972
# ...        ...        ...
# 1569  2.079442   2.116679
# 3966  2.564949   2.224062
# 97    1.492904   1.601239
# 4166  4.043051   3.615894
# 4868  2.847812   2.845096
#
# [1066 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("MAE: " + str(mean_absolute_error(y_pred1, y_valid)))
print("MSE: " + str(mean_squared_error(y_pred1, y_valid)))
# Out:
# MAE: 0.1688356442851499
# MSE: 0.053525239833591774

# %%
regressor1.score(X_valid1,y_valid)
# Out:
# 0.8949791954474973

# %%
plt.scatter(y_valid,y_pred1)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

regressor2 = RandomForestRegressor(n_estimators=20, random_state=0)
regressor2.fit(X_train, y_train)
y_pred2 = regressor2.predict(X_valid)

# %%
df2= pd.DataFrame({'Actual': y_valid, 'Predicted': y_pred2})
df2
# Out:
#         Actual  Predicted
# 1407  2.802754   2.927667
# 5121  1.252763   1.192525
# 2765  1.704748   1.864701
# 1856  1.808289   1.861504
# 748   1.163151   1.125915
# ...        ...        ...
# 1569  2.079442   2.210964
# 3966  2.564949   2.465200
# 97    1.492904   1.394071
# 4166  4.043051   4.108150
# 4868  2.847812   2.923418
#
# [1066 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("MAE: " + str(mean_absolute_error(y_pred2, y_valid)))
print("MSE: " + str(mean_squared_error(y_pred2, y_valid)))
# Out:
# MAE: 0.13163010478037507
# MSE: 0.03480843627817639

# %%
regressor2.score(X_valid,y_valid)
# Out:
# 0.9317030620598099

# %%
plt.scatter(y_valid,y_pred2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor
regressor3 = DecisionTreeRegressor(random_state=0)
regressor3.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred3=regressor3.predict(X_valid)

# %%
regressor3.score(X_valid,y_valid)
# Out:
# 0.8577533571421636

# %%
df3= pd.DataFrame({'Actual': y_valid, 'Predicted': y_pred3})
df3
# Out:
#         Actual  Predicted
# 1407  2.802754   3.040706
# 5121  1.252763   1.321756
# 2765  1.704748   1.677097
# 1856  1.808289   2.014903
# 748   1.163151   1.131402
# ...        ...        ...
# 1569  2.079442   2.066863
# 3966  2.564949   2.639057
# 97    1.492904   1.160021
# 4166  4.043051   3.970292
# 4868  2.847812   2.944439
#
# [1066 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("MAE: " + str(mean_absolute_error(y_pred3, y_valid)))
print("MSE: " + str(mean_squared_error(y_pred3, y_valid)))
# Out:
# MAE: 0.17961000326360307
# MSE: 0.07249787989086139

# %%
regressor3.score(X_valid,y_valid)
# Out:
# 0.8577533571421636

# %%
plt.scatter(y_valid,y_pred3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # GRADIENT BOOSTING REGRESSION TREE MODEL

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %%
gbm = GradientBoostingRegressor()

# %%
gbm.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred4=gbm.predict(X_valid)

# %%
gbm.score(X_valid,y_valid)
# Out:
# 0.9128340903794111

# %%
df4= pd.DataFrame({'Actual': y_valid, 'Predicted': y_pred4})
df4
# Out:
#         Actual  Predicted
# 1407  2.802754   2.990934
# 5121  1.252763   1.152716
# 2765  1.704748   1.937076
# 1856  1.808289   1.924241
# 748   1.163151   1.138173
# ...        ...        ...
# 1569  2.079442   2.204918
# 3966  2.564949   2.529913
# 97    1.492904   1.416310
# 4166  4.043051   3.766803
# 4868  2.847812   2.950566
#
# [1066 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("MAE: " + str(mean_absolute_error(y_pred4, y_valid)))
print("MSE: " + str(mean_squared_error(y_pred4, y_valid)))
# Out:
# MAE: 0.15566704568850614
# MSE: 0.04442525685872805

# %%
plt.scatter(y_valid,y_pred4)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# After applying different models I noticed that Random Forest Regressor model has the least error and highest acccuracy.

# %%
final=regressor2.predict(car_test)
final=np.exp(final)-1
final=final.round(2)

# %%
output=pd.DataFrame({'predicted price':final})
output
# Out:
#       predicted price
# 0                3.19
# 1                2.80
# 2               16.74
# 3                4.02
# 4                4.45
# ...               ...
# 1229             4.23
# 1230             6.53
# 1231             2.57
# 1232             4.14
# 1233            19.32
#
# [1234 rows x 1 columns]

# %%
output.to_excel('submission.xlsx', index=False)

# %%
Company=car_test['Company']

# %%
plt.scatter(Company,output)
plt.xlabel('Company')
plt.ylabel('output')
# Out:
# Text(0, 0.5, 'output')

# %% [markdown]
# I took the log of prices during training and testing data to improve the accuracy of the model and reduce the error.Then for predicting the price be careful to take exponent to get the actual price.
